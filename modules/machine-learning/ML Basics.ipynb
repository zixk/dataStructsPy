# %% [markdown]
# # 1. Importing Data and Manipulation

# %%
import pandas as pd
data_frame = pd.read_csv('data/netflix_titles.csv')
data_frame.head(10)
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
# 5  80163890  TV Show                                  Apaches
# 6  70304989    Movie                                 Automata
# 7  80164077    Movie       Fabrizio Copano: Solo pienso en mi
# 8  80117902  TV Show                             Fire Chasers
# 9  70304990    Movie                              Good People
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                 Fernando Lebrija
# 5                              NaN
# ...

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   object
#  2   title         6234 non-null   object
#  3   director      4265 non-null   object
#  4   cast          5664 non-null   object
#  5   country       5758 non-null   object
#  6   date_added    6223 non-null   object
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   object
#  9   duration      6234 non-null   object
#  10  listed_in     6234 non-null   object
#  11  description   6234 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 584.6+ KB

# %%
data_frame.shape
# Out:
# (6234, 12)

# %%
data_frame.describe()
# Out:
#             show_id  release_year
# count  6.234000e+03    6234.00000
# mean   7.670368e+07    2013.35932
# std    1.094296e+07       8.81162
# min    2.477470e+05    1925.00000
# 25%    8.003580e+07    2013.00000
# 50%    8.016337e+07    2016.00000
# 75%    8.024489e+07    2018.00000
# max    8.123573e+07    2020.00000

# %%
data_frame['title'].head()
# Out:
# 0    Norm of the North: King Sized Adventure
# 1                 Jandino: Whatever it Takes
# 2                         Transformers Prime
# 3           Transformers: Robots in Disguise
# 4                               #realityhigh
# Name: title, dtype: object

# %%
data_frame[data_frame['country'] == 'Poland'].head()
# Out:
#       show_id     type                             title             director  \
# 250  80126566  TV Show                 Wartime Portraits                  NaN
# 794  81168345    Movie  Escape from the "Liberty" Cinema  Wojciech Marczewski
# 805  81168348    Movie             Jealousy and medicine      Janusz Majewski
# 829  81168342    Movie                        The Cruise       Marek Piwowski
# 835  81168343    Movie                          The lynx   Stanisław Różewicz
#
#                                                   cast country  \
# 250                                                NaN  Poland
# 794  Janusz Gajos, Zbigniew Zamachowski, Teresa Mar...  Poland
# 805  Mariusz Dmochowski, Ewa Krzyżewska, Włodzimier...  Poland
# 829  Jan Himilsbach, Stanislaw Tym, Jerzy Dobrowols...  Poland
# 835  Jerzy Radziwiłowicz, Franciszek Pieczka, Piotr...  Poland
#
#              date_added  release_year rating  duration  \
# 250  September 15, 2016          2014  TV-MA  1 Season
# ...

# %%
data_frame.sort_values('release_year', ascending=False).head()
# Out:
#        show_id     type                          title  \
# 3467  81011449  TV Show                 Medical Police
# 3249  81006825    Movie  All the Freckles in the World
# 3220  80997687  TV Show                        Dracula
# 3427  81060049    Movie     Leslie Jones: Time Machine
# 3436  80239306  TV Show     The Healing Powers of Dude
#
#                        director  \
# 3467                        NaN
# 3249               Yibrán Asuad
# 3220                        NaN
# 3427  David Benioff, D.B. Weiss
# 3436                        NaN
#
#                                                    cast         country  \
# 3467  Erinn Hayes, Rob Huebel, Malin Akerman, Rob Co...   United States
# 3249  Hánssel Casillas, Loreto Peralta, Andrea Sutto...          Mexico
# 3220            Claes Bang, Dolly Wells, John Heffernan  United Kingdom
# 3427                                       Leslie Jones   United States
# ...

# %% [markdown]
# # 2. Cleaning Data

# %%
df_shows = pd.DataFrame(data_frame, columns=['title', 'rating', 'listed_in'])

df_comedy_shows = df_shows[df_shows['listed_in'].str.contains('Comed')]
df_comedy_shows.head()
# Out:
#                                       title rating  \
# 0   Norm of the North: King Sized Adventure  TV-PG
# 1                Jandino: Whatever it Takes  TV-MA
# 4                              #realityhigh  TV-14
# 7        Fabrizio Copano: Solo pienso en mi  TV-MA
# 10              Joaquín Reyes: Una y no más  TV-MA
#
#                              listed_in
# 0   Children & Family Movies, Comedies
# 1                      Stand-Up Comedy
# 4                             Comedies
# 7                      Stand-Up Comedy
# 10                     Stand-Up Comedy

# %%
df_all_ages = df_comedy_shows[df_comedy_shows['rating']=='TV-G']
df_all_ages.head()
# Out:
#                             title rating  \
# 1034  Luccas Neto in: Summer Camp   TV-G
# 1043         A Holiday Engagement   TV-G
# 1205          A Fairly Odd Summer   TV-G
# 1206       Bella and the Bulldogs   TV-G
# 1211                       Jinxed   TV-G
#
#                                               listed_in
# 1034                 Children & Family Movies, Comedies
# 1043  Children & Family Movies, Comedies, Romantic M...
# 1205                 Children & Family Movies, Comedies
# 1206                              Kids' TV, TV Comedies
# 1211                 Children & Family Movies, Comedies
